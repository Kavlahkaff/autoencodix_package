# %% [markdown]
# # How To Use Maskix
#
# Maskix is our implementation of a variational autoencoder.
# This tutorial follows the structure of our `Getting Started - Vanillix`, but is much less extensive, because
# our pipeline works similarly for different architectures, so here we focus only on Maskix specifics.
#
# **AUTOENCODIX** supports far more functionality than shown here, so we’ll also point to advanced tutorials where relevant.
#
# **IMPORTANT**
#
# > This tutorial only shows the specifics of the Maskix pipeline. If you're unfamiliar with general concepts,
# > we recommend following the `Getting Started - Vanillix` tutorial first.
#
# ## What You'll Learn
#
# You’ll learn how to:
#
# 1. **Theory primer** of the Maskix architecture. <br><br>
# 2. **Initialize** the pipeline and run the pipeline. <br><br>
# 3. Understand Maskix-specific **config parameters*. <br><br>
# 4. **Access & Visualize** the results effectively. <br><br>
# 5. Pass **custom masking fucntions**. <br><br>
# 6. How to use Maskix for **data imputation** <br><br>
# 7. **Save, load, and reuse** a trained pipeline. <br><br>
#
#
# ## 1) Theory Primer
#
# Maskix adapts the scMAE (single-cell Masked Autoencoder) framework from Fang et al. (2024) for single-cell RNA-seq analysis. The model learns useful representations by corrupting the input expression matrix and training the network both to reconstruct the original data and to identify which entries were perturbed. This encourages the model to capture gene–gene (or feature–feature) relationships in high-dimensional, noisy datasets. Although originally designed for single-cell data, the same approach applies to other domains.
#
# Each training iteration follows this corruption process:
#
# 1. Sample a Bernoulli distribution to determine which entries should be perturbed, producing a binary mask with the same shape as the input.
# 2. For each gene (or feature), generate a random permutation of sample indices.
# 3. For all positions marked as masked, replace the original value with the value from the permuted index for that feature.
#
# The corrupted input is encoded into a low-dimensional latent representation. In parallel, a mask predictor takes the latent space as input and estimates which positions were masked. The predicted mask is then concatenated with the latent representation and passed into a decoder that attempts to reconstruct the original values.
#
# Training uses two loss components. The mask predictor is optimized with binary cross-entropy against the true mask. Reconstruction uses a weighted mean-squared error where masked entries receive higher weight, controlled by the hyperparameter `delta_mask_corrupted`. The total loss is the weighted sum of these components, balanced by the hyperparameter `delta_mask_predictor`.

# %% [markdown]
# ## Requirements 1: Be in the correct directory (execute below)

# %%
import os

p = os.getcwd()
d = "autoencodix_package"
if d not in p:
    raise FileNotFoundError(f"'{d}' not found in path: {p}")
os.chdir(os.sep.join(p.split(os.sep)[: p.split(os.sep).index(d) + 1]))
print(f"Changed to: {os.getcwd()}")
# Out:
# Changed to: /Users/maximilianjoas/development/autoencodix_package

# %% [markdown]
# ## Requirements 2: Obtain tutorial data or use own data
# We use a dataset from the [Fang et al. (2024)](https://doi.org/10.1093/bioinformatics/btae020), with can be donwloaded [here](https://cloud.scadsai.uni-leipzig.de/index.php/s/BP8YzDef4nSfgwj/download/GSE84133_human_combined_final.h5ad), this needs to be moved to `data/raw`. Alternatively you can use your own single-cell dataset (Maskix works with other datatypes, but in this example we expect single cell data: `h5ad`) file and replace the variable `sc_path`.

# %% [markdown]
# ## 2) Initialize and Run Maskix
# As for every other pipline, we need to perform the following steps:
# - import relevant classes
# - define a config
# - init the pipeline
# - call the run step

# %%
import autoencodix as acx
from autoencodix.configs import MaskixConfig
from autoencodix.configs.default_config import DataInfo, DataConfig, DataCase

sc_path = os.path.join("data/raw", "GSE84133_human_combined_final.h5ad")
config = MaskixConfig(
    epochs=30,
    checkpoint_interval=10,
    k_filter=1000,
    batch_size=64,
    data_config=DataConfig(
        annotation_columns=["assigned_cluster"],
        data_info={
            "multi_sc": DataInfo(
                file_path=sc_path, is_single_cell=True, data_type="NUMERIC"
            )
        },
    ),
    data_case=DataCase.MULTI_SINGLE_CELL,
)
maskix = acx.Maskix(config=config)
# Out:
# /Users/maximilianjoas/development/autoencodix_package/src/autoencodix/configs/default_config.py:424: UserWarning: annotation_columns in DataConfig is deprecated. Please set it directly in DefaultConfig instead.
#   warnings.warn(

# %%
maskix_result = maskix.run()
# Out:
# Number of common cells: 8569
# mudata: View of MuData object with n_obs × n_vars = 8569 × 20125
#   obs:	'barcode', 'assigned_cluster', 'sample_id'
#   1 modality
#     multi_sc:	8569 x 20125
#       obs:	'barcode', 'assigned_cluster', 'sample_id'
# Processing 1 MuData objects: ['multi_sc']
# Processing train modality: multi_sc
# Processing valid split
# Processing valid modality: multi_sc
# Processing test split
# Processing test modality: multi_sc
# /Users/maximilianjoas/development/autoencodix_package/src/autoencodix/losses/maskix_loss.py:38: UserWarning: You chose loss reduction: sum, this deviates from the implementation in the literature for this architecture, the authors used 'mean'
#   warnings.warn(
# Epoch 1 - Train Loss: 457.8041
# Sub-losses: recon_loss: 321.2651, mask_loss: 516.3207
# Epoch 1 - Valid Loss: 371.5691
# Sub-losses: recon_loss: 342.8383, mask_loss: 383.8823
# Epoch 2 - Train Loss: 361.8789
# Sub-losses: recon_loss: 315.2352, mask_loss: 381.8691
# Epoch 2 - Valid Loss: 361.6907
# Sub-losses: recon_loss: 323.9272, mask_loss: 377.8750
# Epoch 3 - Train Loss: 356.5615
# Sub-losses: recon_loss: 304.4148, mask_loss: 378.9101
# Epoch 3 - Valid Loss: 357.9536
# Sub-losses: recon_loss: 317.3140, mask_loss: 375.3705
# Epoch 4 - Train Loss: 355.5755
# Sub-losses: recon_loss: 301.8102, mask_loss: 378.6177
# Epoch 4 - Valid Loss: 356.5083
# Sub-losses: recon_loss: 313.1274, mask_loss: 375.1001
# Epoch 5 - Train Loss: 354.0301
# Sub-losses: recon_loss: 297.0726, mask_loss: 378.4404
# Epoch 5 - Valid Loss: 357.1317
# Sub-losses: recon_loss: 314.5344, mask_loss: 375.3876
# Epoch 6 - Train Loss: 353.7900
# Sub-losses: recon_loss: 295.8666, mask_loss: 378.6143
# Epoch 6 - Valid Loss: 356.3735
# Sub-losses: recon_loss: 313.7656, mask_loss: 374.6341
# Epoch 7 - Train Loss: 353.3161
# Sub-losses: recon_loss: 296.1298, mask_loss: 377.8245
# Epoch 7 - Valid Loss: 355.8480
# Sub-losses: recon_loss: 310.0805, mask_loss: 375.4626
# Epoch 8 - Train Loss: 352.5523
# Sub-losses: recon_loss: 292.7871, mask_loss: 378.1659
# Epoch 8 - Valid Loss: 356.3073
# Sub-losses: recon_loss: 311.1442, mask_loss: 375.6629
# Epoch 9 - Train Loss: 351.9220
# Sub-losses: recon_loss: 291.7625, mask_loss: 377.7046
# Epoch 9 - Valid Loss: 353.7353
# Sub-losses: recon_loss: 307.8141, mask_loss: 373.4158
# Epoch 10 - Train Loss: 351.1512
# Sub-losses: recon_loss: 289.8044, mask_loss: 377.4427
# Epoch 10 - Valid Loss: 354.2984
# Sub-losses: recon_loss: 307.1571, mask_loss: 374.5019
# Epoch 11 - Train Loss: 351.0478
# Sub-losses: recon_loss: 289.9299, mask_loss: 377.2412
# Epoch 11 - Valid Loss: 354.8406
# Sub-losses: recon_loss: 307.5496, mask_loss: 375.1081
# Epoch 12 - Train Loss: 350.5586
# Sub-losses: recon_loss: 288.5765, mask_loss: 377.1224
# Epoch 12 - Valid Loss: 354.7863
# Sub-losses: recon_loss: 310.2115, mask_loss: 373.8898
# Epoch 13 - Train Loss: 350.6452
# Sub-losses: recon_loss: 288.0866, mask_loss: 377.4560
# Epoch 13 - Valid Loss: 354.0568
# Sub-losses: recon_loss: 308.0187, mask_loss: 373.7875
# Epoch 14 - Train Loss: 350.9179
# Sub-losses: recon_loss: 290.2122, mask_loss: 376.9347
# Epoch 14 - Valid Loss: 353.5617
# Sub-losses: recon_loss: 305.6521, mask_loss: 374.0944
# Epoch 15 - Train Loss: 350.0593
# Sub-losses: recon_loss: 287.7112, mask_loss: 376.7799
# Epoch 15 - Valid Loss: 351.3506
# Sub-losses: recon_loss: 300.9334, mask_loss: 372.9581
# Epoch 16 - Train Loss: 349.7764
# Sub-losses: recon_loss: 287.0972, mask_loss: 376.6389
# Epoch 16 - Valid Loss: 353.5716
# Sub-losses: recon_loss: 308.4453, mask_loss: 372.9114
# Epoch 17 - Train Loss: 349.7999
# Sub-losses: recon_loss: 286.4900, mask_loss: 376.9328
# Epoch 17 - Valid Loss: 351.2190
# Sub-losses: recon_loss: 299.2309, mask_loss: 373.4997
# Epoch 18 - Train Loss: 348.7309
# Sub-losses: recon_loss: 283.2122, mask_loss: 376.8103
# Epoch 18 - Valid Loss: 351.8295
# Sub-losses: recon_loss: 301.1507, mask_loss: 373.5490
# Epoch 19 - Train Loss: 348.6362
# Sub-losses: recon_loss: 283.1555, mask_loss: 376.6994
# Epoch 19 - Valid Loss: 355.4593
# Sub-losses: recon_loss: 312.2662, mask_loss: 373.9706
# Epoch 20 - Train Loss: 348.1426
# Sub-losses: recon_loss: 282.8636, mask_loss: 376.1193
# Epoch 20 - Valid Loss: 352.3706
# Sub-losses: recon_loss: 300.9604, mask_loss: 374.4036
# Epoch 21 - Train Loss: 348.1805
# Sub-losses: recon_loss: 281.6141, mask_loss: 376.7090
# Epoch 21 - Valid Loss: 351.3304
# Sub-losses: recon_loss: 300.0887, mask_loss: 373.2911
# Epoch 22 - Train Loss: 348.4245
# Sub-losses: recon_loss: 283.4456, mask_loss: 376.2726
# Epoch 22 - Valid Loss: 351.6696
# Sub-losses: recon_loss: 303.0271, mask_loss: 372.5164
# Epoch 23 - Train Loss: 348.2578
# Sub-losses: recon_loss: 282.8971, mask_loss: 376.2696
# Epoch 23 - Valid Loss: 352.5511
# Sub-losses: recon_loss: 305.1005, mask_loss: 372.8870
# Epoch 24 - Train Loss: 348.6751
# Sub-losses: recon_loss: 283.6475, mask_loss: 376.5440
# Epoch 24 - Valid Loss: 350.5231
# Sub-losses: recon_loss: 297.8418, mask_loss: 373.1008
# Epoch 25 - Train Loss: 347.7773
# Sub-losses: recon_loss: 281.2268, mask_loss: 376.2989
# Epoch 25 - Valid Loss: 350.4386
# Sub-losses: recon_loss: 295.8410, mask_loss: 373.8376
# Epoch 26 - Train Loss: 348.5824
# Sub-losses: recon_loss: 283.7155, mask_loss: 376.3825
# Epoch 26 - Valid Loss: 352.0229
# Sub-losses: recon_loss: 303.0566, mask_loss: 373.0085
# Epoch 27 - Train Loss: 348.7501
# Sub-losses: recon_loss: 283.9181, mask_loss: 376.5353
# Epoch 27 - Valid Loss: 350.9869
# Sub-losses: recon_loss: 299.2550, mask_loss: 373.1577
# Epoch 28 - Train Loss: 347.7498
# Sub-losses: recon_loss: 281.8230, mask_loss: 376.0041
# Epoch 28 - Valid Loss: 351.2245
# Sub-losses: recon_loss: 302.0846, mask_loss: 372.2845
# Epoch 29 - Train Loss: 347.0939
# Sub-losses: recon_loss: 279.5290, mask_loss: 376.0502
# Epoch 29 - Valid Loss: 349.8023
# Sub-losses: recon_loss: 296.6521, mask_loss: 372.5810
# Epoch 30 - Train Loss: 347.6182
# Sub-losses: recon_loss: 280.4810, mask_loss: 376.3912
# Epoch 30 - Valid Loss: 349.7180
# Sub-losses: recon_loss: 294.1683, mask_loss: 373.5250

# %% [markdown]
# ## 3) Understanding Maskix-specific Config Parameters
#
# As described in the [theory section](#1-theory-primer), we implemented the architecture from [Fang et al. (2024)](https://doi.org/10.1093/bioinformatics/btae020), with weighted loss terms and a specific encoder–decoder design. To make this adaptable within our framework, we expose the following configuration parameters:
#
# * **maskix_hidden_dim**: Hidden dimension used in the Maskix encoder and decoder, matching the scMAE reference architecture by default.
# * **maskix_swap_prob**: Bernoulli probability controlling how often feature values are swapped during input corruption.
# * **delta_mask_predictor**: Weighting factor for the mask prediction loss in the total training objective.
# * **delta_mask_corrupted**: Weighting factor that increases the reconstruction penalty on corrupted entries.
# * **maskix_architecture**: Selects between the default scMAE architecture or a custom architecture configured through `n_layers` and `enc_factor`.
#
# You can find the default values by running the following:

# %%
MaskixConfig.print_schema(
    filter_params=[
        "maskix_hidden_dim",
        "maskix_swap_prob",
        "delta_mask_predictor",
        "delta_mask_corrupted",
        "maskix_architecture",
    ]
)
# Out:
# Valid Keyword Arguments:
# --------------------------------------------------
#
# maskix_hidden_dim:
#   Type: <class 'int'>
#   Default: 128
#   Description: The Maskix implementation follows https://doi.org/10.1093/bioinformatics/btae020. The authors use a hidden dimension 0f 256 for their neural network, so we set this as default
#
# maskix_swap_prob:
#   Type: <class 'float'>
#   Default: 0.2
#   Description: For the Maskix input_data masinkg, we sample a probablity if samples within one gene should be swapt. This is done with a Bernoulli distribution, maskix_swap_prob is the probablity passed to the bernoulli distribution
#
# delta_mask_predictor:
#   Type: <class 'float'>
#   Default: 0.7
#   Description: Delt weighting factor of the mask predictin loss term for the Maskix
#
# delta_mask_corrupted:
#   Type: <class 'float'>
#   Default: 0.75
#   Description: For the Maskix: if >0.5 this gives more weight for the correct reconstruction of corrupted input
#
# maskix_architecture:
#   Type: typing.Literal['scMAE', 'custom']
#   Default: scMAE
#   Description: If you want to customize your maskix architecture                     via 'n_layers' or 'enc_factor, you need to set this to 'custom'.                     Otherwise, the architecture for the scMAE from  https://doi.org/10.1093/bioinformatics/btae020 is used

# %% [markdown]
# ## 4) Access & Visualize Results Effectively
#
# In addition to the results that the Vanillix pipeline provided, we can access:
# - `total`, `reconstruction`, and `masked` losses
#
# A note on the different loss types:
# For our maksed autoencoder, the total loss consists of a reconstruction loss and a mask predictor los
# To investigate these losses, the `result` object has the attribute `sub_losses`.
# This is a `LossRegistry` with the name of the loss as the key, and the value is a `TrainingDynamics` object, which can be accessed in the same way as for the Vanillix results.
#
# For more details, check `Tutorials/DeepDives/PipelineOutputTutorial.ipynb`.

# %%
sub_losses = maskix_result.sub_losses
print("Sub Losses:")
print(f"keys: {sub_losses.keys()}")
print("\n")
recon_dyn = sub_losses.get(key="recon_loss")
print("Value of reconstruction loss in epoch 4 for train split")
print(recon_dyn.get(split="train", epoch=4))
# Out:
# Sub Losses:
# keys: dict_keys(['recon_loss', 'mask_loss'])
#
#
# Value of reconstruction loss in epoch 4 for train split
# 297.0726140484328

# %% [markdown]
# As for our other pipelines we can visualize the loss with `.show_result()`
# For more infos on visualization, see: `Tutorials/DeepDives/VisualizeTutorial.ipynb`

# %%
maskix.show_result()
# Out:
# Creating plots ...
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.

# %% [markdown]
# ## 5) Adding a Custom Masking Function to `MaskixTrainer`
#
# `MaskixTrainer` supports replacing its default corruption mechanism with a user-defined masking function. This enables experimentation with alternative masking strategies while ensuring compatibility with the trainer’s data flow.
#
# #### How to Add a Custom Masking Function
#
# Provide your masking function at initialization:
#
# ```python
# # We assume that config is defined and other imports are done (see above)
#
# def my_masking_fn(x: torch.Tensor, strength: float = 0.2):
#     noise = torch.randn_like(x) * strength
#     return x + noise  # must return ONLY a single tensor in shape of input tensor
#
# masking_fn_kwargs = {"strength": 0.1}
# maskix = acx.Maskix(config=config, masking_fn, masking_fn_kwargs
# )
# ```
# #### Requirements for a Custom Masking Function
#
# A custom masking function must satisfy the following constraints:
#
# 1. **It must accept a `torch.Tensor` as the first positional argument.**
#    The trainer passes the input mini-batch `X` directly into the function.
#
# 2. **It must return exactly one value: a `torch.Tensor`.**
#    The trainer does not consume or propagate additional outputs.
#    Returning tuples or multiple values is not allowed.
#
# 3. **The returned tensor must have the same shape as the input tensor.**
#    Any shape mismatch will raise a validation error.
#
# 4. **The function must operate on the device of the input tensor.**
#    The function must not assume the tensor resides on the CPU; it must operate on the device of `x`.
#
# 5. **Any additional parameters must be passed via `masking_fn_kwargs`.**
#    These keyword arguments provide a clean separation between trainer configuration and masking logic.
#
# ##### Example
# This is our default masking method:
# ```python
#     def _maskix_hook(
#         self, X: torch.Tensor
#     ) -> torch.Tensor
#         # expand probablities for bernoulli sampling to match input shape
#         probs = self._mask_probas.expand(X.shape)
#
#         # Create the Boolean Mask (1 = Swap, 0 = Keep)
#         should_swap = torch.bernoulli(probs).bool()
#
#         # COLUMN-WISE SHUFFLING
#         # We generate a random float matrix and argsort it along dim=0.
#         # This gives us independent random indices for every column.
#         rand_indices = torch.rand(X.shape, device=X.device).argsort(dim=0)
#
#         # Use gather to reorder X based on these random indices
#         shuffled_X = torch.gather(X, 0, rand_indices)
#         corrupted_X = torch.where(should_swap, shuffled_X, X)
#
#         return corrupted_X
# ```

# %% [markdown]
# ##### Code Example

# %%
import torch
import autoencodix as acx
from autoencodix.configs import MaskixConfig
from autoencodix.configs.default_config import DataInfo, DataConfig, DataCase


def my_masking_fn(x: torch.Tensor, strength: float = 0.2):
    # Noise is created with the same shape, dtype, and device as `x`
    # Because of randn_lie, if you use other function, take care of 
    # device and dtype casting.
    noise = torch.randn_like(x) * strength
    return x + noise


kwargs = {"strength": 0.5}


sc_path = os.path.join("data/raw", "GSE84133_human_combined_final.h5ad")
config = MaskixConfig(
    epochs=5,
    checkpoint_interval=2,
    batch_size=64,
    data_config=DataConfig(
        annotation_columns=["assigned_cluster"],
        data_info={
            "multi_sc": DataInfo(
                file_path=sc_path, is_single_cell=True, data_type="NUMERIC"
            )
        },
    ),
    data_case=DataCase.MULTI_SINGLE_CELL,
)
maskix = acx.Maskix(config=config, masking_fn=my_masking_fn, masking_fn_kwargs=kwargs)
# Out:
# /Users/maximilianjoas/development/autoencodix_package/src/autoencodix/configs/default_config.py:424: UserWarning: annotation_columns in DataConfig is deprecated. Please set it directly in DefaultConfig instead.
#   warnings.warn(

# %%
result = maskix.run()
# Out:
# Number of common cells: 8569
# mudata: View of MuData object with n_obs × n_vars = 8569 × 20125
#   obs:	'barcode', 'assigned_cluster', 'sample_id'
#   1 modality
#     multi_sc:	8569 x 20125
#       obs:	'barcode', 'assigned_cluster', 'sample_id'
# Processing 1 MuData objects: ['multi_sc']
# Processing train modality: multi_sc
# Processing valid split
# Processing valid modality: multi_sc
# Processing test split
# Processing test modality: multi_sc
# /Users/maximilianjoas/development/autoencodix_package/src/autoencodix/losses/maskix_loss.py:38: UserWarning: You chose loss reduction: sum, this deviates from the implementation in the literature for this architecture, the authors used 'mean'
#   warnings.warn(
# Epoch 1 - Train Loss: 12105.6198
# Sub-losses: recon_loss: 12911.1079, mask_loss: 11760.4107
# Epoch 1 - Valid Loss: 13339.3089
# Sub-losses: recon_loss: 17079.2109, mask_loss: 11736.4939
# Epoch 2 - Train Loss: 12034.6743
# Sub-losses: recon_loss: 12762.1821, mask_loss: 11722.8852
# Epoch 2 - Valid Loss: 13313.6618
# Sub-losses: recon_loss: 17065.6675, mask_loss: 11705.6594
# Epoch 3 - Train Loss: 12011.3756
# Sub-losses: recon_loss: 12722.0719, mask_loss: 11706.7913
# Epoch 3 - Valid Loss: 13302.2060
# Sub-losses: recon_loss: 17006.2726, mask_loss: 11714.7488
# Epoch 4 - Train Loss: 11996.9393
# Sub-losses: recon_loss: 12701.4683, mask_loss: 11694.9982
# Epoch 4 - Valid Loss: 13291.2394
# Sub-losses: recon_loss: 17039.3362, mask_loss: 11684.9120
# Epoch 5 - Train Loss: 11989.2359
# Sub-losses: recon_loss: 12696.9138, mask_loss: 11685.9453
# Epoch 5 - Valid Loss: 13284.6471
# Sub-losses: recon_loss: 17012.5390, mask_loss: 11686.9790
# /Users/maximilianjoas/development/autoencodix_package/src/autoencodix/visualize/_general_visualizer.py:34: UserWarning: Model weights plot is skipped since input dimension 17273 is larger than 3000 and heatmap would be too large.
#   warnings.warn(

# %% [markdown]
# ## 6) Use Maskix to Impute Data
#
# You can also input corrupted/missing data and use `Maskix` to impute the data. Here we recommend using a custom masking function. For example, if you want to impute missing values, an imputer could randomly replace values with zeros.
#
# Then you could use `Maskix` to clean your data and use the cleaned data to run your analysis, for example another autoencodix pipeline or anything else. In our mock example we will do the following:
#
# - Create corrupted data with missing values
# - Remove the "missing" data
# - Train Maskix with clean data, but with a custom imputer that mimics missing data
# - Feed corrupted data into trained Maskix and obtain imputed data
# - Train Varix with:
#     - Original data with missing values
#     - Imputed data
# - Compare results

# %% [markdown]
# #### Create Corrupted Data
# We will use our single-cell example from before and use maskix to preprocess the data, which makes the artificall corruption process more robust, because we make sure to corrupt informative features/samples.

# %% [markdown]
# ##

# %%
import torch
import autoencodix as acx
from autoencodix.configs import MaskixConfig
from autoencodix.configs.default_config import DataInfo, DataConfig, DataCase


sc_path = os.path.join("data/raw", "GSE84133_human_combined_final.h5ad")
config = MaskixConfig(
    epochs=30,
    checkpoint_interval=2,
    k_filter=1000,
    batch_size=64,
    data_config=DataConfig(
        annotation_columns=["assigned_cluster"],
        data_info={
            "multi_sc": DataInfo(
                file_path=sc_path, is_single_cell=True, data_type="NUMERIC"
            )
        },
    ),
    data_case=DataCase.MULTI_SINGLE_CELL,
)
maskix_orig = acx.Maskix(config=config)
maskix_orig.preprocess()
data = maskix_orig.result.datasets
# Out:
# /Users/maximilianjoas/development/autoencodix_package/src/autoencodix/configs/default_config.py:424: UserWarning: annotation_columns in DataConfig is deprecated. Please set it directly in DefaultConfig instead.
#   warnings.warn(
# Number of common cells: 8569
# mudata: View of MuData object with n_obs × n_vars = 8569 × 20125
#   obs:	'barcode', 'assigned_cluster', 'sample_id'
#   1 modality
#     multi_sc:	8569 x 20125
#       obs:	'barcode', 'assigned_cluster', 'sample_id'
# Processing 1 MuData objects: ['multi_sc']
# Processing train modality: multi_sc
# Processing valid split
# Processing valid modality: multi_sc
# Processing test split
# Processing test modality: multi_sc

# %% [markdown]
# Now we will randomly set data do zero with.

# %%
import torch
import copy
from autoencodix.data._numeric_dataset import NumericDataset
def drop_samples(ds: NumericDataset):
    """Randomly drops samples in .data and according .metadata (pd.DataFrame) and sample_ids"""
    data = ds.data
    n_samples = data.shape[0]
    drop_prob = 0.3
    keep_mask = torch.bernoulli((1 - drop_prob) * torch.ones(n_samples)).bool()
    # replace entries with zero
    imputed_data = data.clone()
    imputed_data[~keep_mask] = 0

    missing_data = data[keep_mask]
    missing_metadata = ds.metadata.iloc[keep_mask.cpu().numpy()].reset_index(drop=True)
    missing_sample_ids = [sid for i, sid in enumerate(ds.sample_ids) if keep_mask[i]]
    ds_with_missing = copy.deepcopy(ds)
    ds_with_missing.data = missing_data
    ds_with_missing.metadata = missing_metadata
    ds_with_missing.sample_ids = missing_sample_ids


    ds_with_zero = copy.deepcopy(ds)
    ds_with_zero.data = imputed_data
    ds_with_zero.metadata = ds.metadata
    ds_with_zero.sample_ids = ds.sample_ids
    return ds_with_missing, ds_with_zero

ds_with_missing = copy.deepcopy(data)
ds_with_zero = copy.deepcopy(data)
missing_train, ds_with_zero_train = drop_samples(ds_with_missing.train)

print(f"Original train data shape: {data.train.data.shape}, shape after corruption: {missing_train.data.shape}")
missing_test, ds_with_zero_test = drop_samples(data.test)
print(f"Original test data shape: {data.test.data.shape}, shape after corruption: {missing_test.data.shape}")
missing_valid, ds_with_zero_valid    = drop_samples(data.valid)
print(f"Original valid data shape: {data.valid.data.shape}, shape after corruption: {missing_valid.data.shape}")
ds_with_missing.train= missing_train
ds_with_missing.test = missing_test
ds_with_missing.valid = missing_valid


ds_with_zero.train= ds_with_zero_train
ds_with_zero.test = ds_with_zero_test
ds_with_zero.valid = ds_with_zero_valid
# clean corruped samples by removing zero values from dataset (drop samples) and also
# Out:
# Original train data shape: torch.Size([5998, 1000]), shape after corruption: torch.Size([4218, 1000])
# Original test data shape: torch.Size([1715, 1000]), shape after corruption: torch.Size([1184, 1000])
# Original valid data shape: torch.Size([856, 1000]), shape after corruption: torch.Size([585, 1000])

# %% [markdown]
# Now we train our Maskix with this clean data, but we will pass a custom imputer that will simulate missing values

# %%
import torch
import autoencodix as acx
from autoencodix.configs import MaskixConfig
from autoencodix.configs.default_config import DataInfo, DataConfig, DataCase


def my_imputer(x: torch.Tensor) -> torch.Tensor:
    "randomly replaces value with zero"
    rand_mask = torch.bernoulli(0.3 * torch.ones(x.shape, device=x.device)).bool()
    rand_mask.to(x.device)
    imputed_x = torch.where(rand_mask, torch.zeros_like(x, device=x.device), x)
    return imputed_x


sc_path = os.path.join("data/raw", "GSE84133_human_combined_final.h5ad")
config = MaskixConfig(
    epochs=30,
    checkpoint_interval=2,
    k_filter=3000,
    skip_preprocessing=True,
    batch_size=64,
    data_config=DataConfig(
        annotation_columns=["assigned_cluster"],
        data_info={
            "multi_sc": DataInfo(
                 is_single_cell=True, data_type="NUMERIC"
            )
        },
    ),
    data_case=DataCase.MULTI_SINGLE_CELL,
)
maskix = acx.Maskix(config=config, masking_fn=my_imputer, data=ds_with_missing)
result = maskix.run()
# Out:
# /Users/maximilianjoas/development/autoencodix_package/src/autoencodix/configs/default_config.py:424: UserWarning: annotation_columns in DataConfig is deprecated. Please set it directly in DefaultConfig instead.
#   warnings.warn(
# /Users/maximilianjoas/development/autoencodix_package/src/autoencodix/losses/maskix_loss.py:38: UserWarning: You chose loss reduction: sum, this deviates from the implementation in the literature for this architecture, the authors used 'mean'
#   warnings.warn(
# Epoch 1 - Train Loss: 564.3817
# Sub-losses: recon_loss: 358.4056, mask_loss: 652.6572
# Epoch 1 - Valid Loss: 540.1934
# Sub-losses: recon_loss: 367.1685, mask_loss: 614.3470
# Epoch 2 - Train Loss: 531.8986
# Sub-losses: recon_loss: 341.5057, mask_loss: 613.4955
# Epoch 2 - Valid Loss: 533.3560
# Sub-losses: recon_loss: 347.6278, mask_loss: 612.9537
# Epoch 3 - Train Loss: 529.0670
# Sub-losses: recon_loss: 334.6120, mask_loss: 612.4048
# Epoch 3 - Valid Loss: 531.4799
# Sub-losses: recon_loss: 342.5255, mask_loss: 612.4604
# Epoch 4 - Train Loss: 527.7503
# Sub-losses: recon_loss: 329.4334, mask_loss: 612.7433
# Epoch 4 - Valid Loss: 532.9402
# Sub-losses: recon_loss: 345.3417, mask_loss: 613.3396
# Epoch 5 - Train Loss: 526.9982
# Sub-losses: recon_loss: 327.0183, mask_loss: 612.7038
# Epoch 5 - Valid Loss: 532.1071
# Sub-losses: recon_loss: 344.8979, mask_loss: 612.3397
# Epoch 6 - Train Loss: 526.3594
# Sub-losses: recon_loss: 324.6463, mask_loss: 612.8080
# Epoch 6 - Valid Loss: 533.5647
# Sub-losses: recon_loss: 348.4148, mask_loss: 612.9146
# Epoch 7 - Train Loss: 525.3949
# Sub-losses: recon_loss: 321.1034, mask_loss: 612.9484
# Epoch 7 - Valid Loss: 530.0846
# Sub-losses: recon_loss: 337.2603, mask_loss: 612.7237
# Epoch 8 - Train Loss: 526.0613
# Sub-losses: recon_loss: 323.9147, mask_loss: 612.6955
# Epoch 8 - Valid Loss: 529.3807
# Sub-losses: recon_loss: 335.3410, mask_loss: 612.5406
# Epoch 9 - Train Loss: 524.8171
# Sub-losses: recon_loss: 320.2070, mask_loss: 612.5071
# Epoch 9 - Valid Loss: 530.8699
# Sub-losses: recon_loss: 340.0908, mask_loss: 612.6324
# Epoch 10 - Train Loss: 524.3720
# Sub-losses: recon_loss: 318.8158, mask_loss: 612.4675
# Epoch 10 - Valid Loss: 530.7731
# Sub-losses: recon_loss: 340.7489, mask_loss: 612.2120
# Epoch 11 - Train Loss: 523.5676
# Sub-losses: recon_loss: 316.7752, mask_loss: 612.1929
# Epoch 11 - Valid Loss: 529.0395
# Sub-losses: recon_loss: 333.3636, mask_loss: 612.9006
# Epoch 12 - Train Loss: 524.1568
# Sub-losses: recon_loss: 317.9717, mask_loss: 612.5218
# Epoch 12 - Valid Loss: 528.0877
# Sub-losses: recon_loss: 330.6358, mask_loss: 612.7100
# Epoch 13 - Train Loss: 522.5967
# Sub-losses: recon_loss: 313.2176, mask_loss: 612.3306
# Epoch 13 - Valid Loss: 528.5958
# Sub-losses: recon_loss: 330.9762, mask_loss: 613.2900
# Epoch 14 - Train Loss: 522.6969
# Sub-losses: recon_loss: 313.3846, mask_loss: 612.4022
# Epoch 14 - Valid Loss: 525.8621
# Sub-losses: recon_loss: 325.3855, mask_loss: 611.7806
# Epoch 15 - Train Loss: 522.3465
# Sub-losses: recon_loss: 312.9899, mask_loss: 612.0707
# Epoch 15 - Valid Loss: 527.9580
# Sub-losses: recon_loss: 330.4963, mask_loss: 612.5845
# Epoch 16 - Train Loss: 522.8752
# Sub-losses: recon_loss: 313.9943, mask_loss: 612.3956
# Epoch 16 - Valid Loss: 526.3068
# Sub-losses: recon_loss: 327.4805, mask_loss: 611.5181
# Epoch 17 - Train Loss: 522.9205
# Sub-losses: recon_loss: 314.4972, mask_loss: 612.2447
# Epoch 17 - Valid Loss: 527.5537
# Sub-losses: recon_loss: 329.1893, mask_loss: 612.5671
# Epoch 18 - Train Loss: 522.4320
# Sub-losses: recon_loss: 313.0971, mask_loss: 612.1469
# Epoch 18 - Valid Loss: 526.5434
# Sub-losses: recon_loss: 327.0324, mask_loss: 612.0481
# Epoch 19 - Train Loss: 522.1792
# Sub-losses: recon_loss: 311.8355, mask_loss: 612.3265
# Epoch 19 - Valid Loss: 526.7207
# Sub-losses: recon_loss: 325.3232, mask_loss: 613.0340
# Epoch 20 - Train Loss: 522.3857
# Sub-losses: recon_loss: 312.9009, mask_loss: 612.1649
# Epoch 20 - Valid Loss: 528.2712
# Sub-losses: recon_loss: 332.6255, mask_loss: 612.1194
# Epoch 21 - Train Loss: 522.5404
# Sub-losses: recon_loss: 312.8785, mask_loss: 612.3955
# Epoch 21 - Valid Loss: 526.1063
# Sub-losses: recon_loss: 326.9020, mask_loss: 611.4796
# Epoch 22 - Train Loss: 522.6717
# Sub-losses: recon_loss: 313.1365, mask_loss: 612.4725
# Epoch 22 - Valid Loss: 526.1164
# Sub-losses: recon_loss: 325.3284, mask_loss: 612.1684
# Epoch 23 - Train Loss: 522.7052
# Sub-losses: recon_loss: 312.8890, mask_loss: 612.6265
# Epoch 23 - Valid Loss: 527.1564
# Sub-losses: recon_loss: 329.3397, mask_loss: 611.9350
# Epoch 24 - Train Loss: 522.1129
# Sub-losses: recon_loss: 311.7694, mask_loss: 612.2601
# Epoch 24 - Valid Loss: 525.7550
# Sub-losses: recon_loss: 323.9335, mask_loss: 612.2500
# Epoch 25 - Train Loss: 522.1768
# Sub-losses: recon_loss: 311.3635, mask_loss: 612.5254
# Epoch 25 - Valid Loss: 526.7987
# Sub-losses: recon_loss: 326.6321, mask_loss: 612.5844
# Epoch 26 - Train Loss: 520.8874
# Sub-losses: recon_loss: 308.0074, mask_loss: 612.1217
# Epoch 26 - Valid Loss: 526.6308
# Sub-losses: recon_loss: 327.6197, mask_loss: 611.9212
# Epoch 27 - Train Loss: 521.2818
# Sub-losses: recon_loss: 308.7486, mask_loss: 612.3675
# Epoch 27 - Valid Loss: 526.1777
# Sub-losses: recon_loss: 323.9622, mask_loss: 612.8416
# Epoch 28 - Train Loss: 521.2016
# Sub-losses: recon_loss: 309.5391, mask_loss: 611.9141
# Epoch 28 - Valid Loss: 524.5680
# Sub-losses: recon_loss: 321.8673, mask_loss: 611.4397
# Epoch 29 - Train Loss: 520.6574
# Sub-losses: recon_loss: 306.9187, mask_loss: 612.2598
# Epoch 29 - Valid Loss: 527.7929
# Sub-losses: recon_loss: 329.7781, mask_loss: 612.6565
# Epoch 30 - Train Loss: 521.0587
# Sub-losses: recon_loss: 308.0655, mask_loss: 612.3415
# Epoch 30 - Valid Loss: 525.6019
# Sub-losses: recon_loss: 324.2222, mask_loss: 611.9075

# %% [markdown]
# No we use the trained maskix to impute our missing data

# %% [markdown]
# Now, we can use the fitted model and use a corrupted input with missing to get a reconstruction without missing values.

# %%
mo_train = maskix.impute(ds_with_zero.train.data)
recons_train = mo_train.reconstruction

mo_test = maskix.impute(ds_with_zero.test.data)
recons_test = mo_test.reconstruction

mo_valid = maskix.impute(ds_with_zero.valid.data)
recons_valid = mo_valid.reconstruction


ds_imputed = copy.deepcopy(ds_with_zero)
ds_imputed.train.data = recons_train
ds_imputed.test.data = recons_test
ds_imputed.valid.data = recons_valid

# %% [markdown]
# We can compare the loss between the imputed data and the original and the reconstructed data and the original.

# %%
# %%capture
# ground truth without missing values
result_orig = maskix_orig.run()

# %%
from torch.nn.functional import mse_loss
original_train = result_orig.datasets.train.data
original_recon = result_orig.reconstructions.get(split="train", epoch=-1)
original_recon_tensor = torch.from_numpy(original_recon)
loss = mse_loss(original_recon_tensor, original_train)
print(f"MSE Loss original reconstruction: {loss}")
loss_imputed = mse_loss(recons_train.to("cpu"), original_train)
print(f"MSE Loss imputed reconstruction: {loss_imputed}")
# Out:
# MSE Loss original reconstruction: 0.8243632316589355
# MSE Loss imputed reconstruction: 0.8500050902366638

# %% [markdown]
# Finally, you can use this data as input for other autoencoders like `varix` or `vanillix`, but also use it for maskix.
# We will train two Varix models, one with the missing data and one with the imputed data and compare the results

# %%
original_train.shape
# Out:
# torch.Size([5998, 1000])

# %%
recons_train.shape
# Out:
# torch.Size([5998, 1000])

# %%
import autoencodix as acx
from autoencodix.configs import VarixConfig
from autoencodix.configs.default_config import DataInfo, DataConfig, DataCase
from autoencodix.data._datasetcontainer import DatasetContainer
import copy

config = VarixConfig(
    epochs=50,
    checkpoint_interval=10,
    batch_size=64,
    skip_preprocessing=True,
    data_config=DataConfig(
        annotation_columns=["assigned_cluster"],
        data_info={"multi_sc": DataInfo(is_single_cell=True, data_type="NUMERIC")},
    ),
    data_case=DataCase.MULTI_SINGLE_CELL,
)

varix_imputed = acx.Varix(config=config, data=ds_imputed)
varix_missing = acx.Varix(config=config, data=ds_with_zero)
# Out:
# /Users/maximilianjoas/development/autoencodix_package/src/autoencodix/configs/default_config.py:424: UserWarning: annotation_columns in DataConfig is deprecated. Please set it directly in DefaultConfig instead.
#   warnings.warn(

# %%
result_imputed = varix_imputed.run()
result_missing = varix_missing.run()
# Out:
# Epoch 1 - Train Loss: 196.5168
# Sub-losses: recon_loss: 196.5167, var_loss: 0.0001, anneal_factor: 0.0000, effective_beta_factor: 0.0000
# Epoch 1 - Valid Loss: 116.3537
# Sub-losses: recon_loss: 116.3536, var_loss: 0.0001, anneal_factor: 0.0000, effective_beta_factor: 0.0000
# Epoch 2 - Train Loss: 127.5935
# Sub-losses: recon_loss: 127.5932, var_loss: 0.0003, anneal_factor: 0.0001, effective_beta_factor: 0.0000
# Epoch 2 - Valid Loss: 88.2960
# Sub-losses: recon_loss: 88.2959, var_loss: 0.0001, anneal_factor: 0.0001, effective_beta_factor: 0.0000
# Epoch 3 - Train Loss: 103.5009
# Sub-losses: recon_loss: 103.5006, var_loss: 0.0003, anneal_factor: 0.0001, effective_beta_factor: 0.0000
# Epoch 3 - Valid Loss: 71.7165
# Sub-losses: recon_loss: 71.7162, var_loss: 0.0003, anneal_factor: 0.0001, effective_beta_factor: 0.0000
# Epoch 4 - Train Loss: 92.4328
# Sub-losses: recon_loss: 92.4323, var_loss: 0.0005, anneal_factor: 0.0002, effective_beta_factor: 0.0000
# Epoch 4 - Valid Loss: 63.2593
# Sub-losses: recon_loss: 63.2588, var_loss: 0.0005, anneal_factor: 0.0002, effective_beta_factor: 0.0000
# Epoch 5 - Train Loss: 82.8850
# Sub-losses: recon_loss: 82.8841, var_loss: 0.0009, anneal_factor: 0.0002, effective_beta_factor: 0.0000
# Epoch 5 - Valid Loss: 53.2539
# Sub-losses: recon_loss: 53.2531, var_loss: 0.0009, anneal_factor: 0.0002, effective_beta_factor: 0.0000
# Epoch 6 - Train Loss: 75.2421
# Sub-losses: recon_loss: 75.2405, var_loss: 0.0016, anneal_factor: 0.0003, effective_beta_factor: 0.0000
# Epoch 6 - Valid Loss: 47.0168
# Sub-losses: recon_loss: 47.0151, var_loss: 0.0017, anneal_factor: 0.0003, effective_beta_factor: 0.0000
# Epoch 7 - Train Loss: 67.2253
# Sub-losses: recon_loss: 67.2224, var_loss: 0.0029, anneal_factor: 0.0005, effective_beta_factor: 0.0001
# Epoch 7 - Valid Loss: 41.9496
# Sub-losses: recon_loss: 41.9467, var_loss: 0.0029, anneal_factor: 0.0005, effective_beta_factor: 0.0001
# Epoch 8 - Train Loss: 64.6072
# Sub-losses: recon_loss: 64.6021, var_loss: 0.0051, anneal_factor: 0.0007, effective_beta_factor: 0.0001
# Epoch 8 - Valid Loss: 40.6821
# Sub-losses: recon_loss: 40.6772, var_loss: 0.0049, anneal_factor: 0.0007, effective_beta_factor: 0.0001
# Epoch 9 - Train Loss: 61.4846
# Sub-losses: recon_loss: 61.4759, var_loss: 0.0086, anneal_factor: 0.0011, effective_beta_factor: 0.0001
# Epoch 9 - Valid Loss: 37.4308
# Sub-losses: recon_loss: 37.4222, var_loss: 0.0085, anneal_factor: 0.0011, effective_beta_factor: 0.0001
# Epoch 10 - Train Loss: 56.3101
# Sub-losses: recon_loss: 56.2956, var_loss: 0.0146, anneal_factor: 0.0017, effective_beta_factor: 0.0002
# Epoch 10 - Valid Loss: 34.7193
# Sub-losses: recon_loss: 34.7049, var_loss: 0.0144, anneal_factor: 0.0017, effective_beta_factor: 0.0002
# Epoch 11 - Train Loss: 56.5290
# Sub-losses: recon_loss: 56.5049, var_loss: 0.0241, anneal_factor: 0.0025, effective_beta_factor: 0.0002
# Epoch 11 - Valid Loss: 33.8616
# Sub-losses: recon_loss: 33.8399, var_loss: 0.0217, anneal_factor: 0.0025, effective_beta_factor: 0.0002
# Epoch 12 - Train Loss: 53.4669
# Sub-losses: recon_loss: 53.4268, var_loss: 0.0401, anneal_factor: 0.0037, effective_beta_factor: 0.0004
# Epoch 12 - Valid Loss: 32.4889
# Sub-losses: recon_loss: 32.4510, var_loss: 0.0380, anneal_factor: 0.0037, effective_beta_factor: 0.0004
# Epoch 13 - Train Loss: 52.7343
# Sub-losses: recon_loss: 52.6695, var_loss: 0.0649, anneal_factor: 0.0055, effective_beta_factor: 0.0005
# Epoch 13 - Valid Loss: 30.5277
# Sub-losses: recon_loss: 30.4597, var_loss: 0.0680, anneal_factor: 0.0055, effective_beta_factor: 0.0005
# Epoch 14 - Train Loss: 52.8029
# Sub-losses: recon_loss: 52.6982, var_loss: 0.1048, anneal_factor: 0.0082, effective_beta_factor: 0.0008
# Epoch 14 - Valid Loss: 30.0731
# Sub-losses: recon_loss: 29.9765, var_loss: 0.0966, anneal_factor: 0.0082, effective_beta_factor: 0.0008
# Epoch 15 - Train Loss: 50.8028
# Sub-losses: recon_loss: 50.6349, var_loss: 0.1680, anneal_factor: 0.0121, effective_beta_factor: 0.0012
# Epoch 15 - Valid Loss: 29.2170
# Sub-losses: recon_loss: 29.0595, var_loss: 0.1575, anneal_factor: 0.0121, effective_beta_factor: 0.0012
# Epoch 16 - Train Loss: 49.7557
# Sub-losses: recon_loss: 49.4967, var_loss: 0.2590, anneal_factor: 0.0180, effective_beta_factor: 0.0018
# Epoch 16 - Valid Loss: 27.5346
# Sub-losses: recon_loss: 27.2947, var_loss: 0.2399, anneal_factor: 0.0180, effective_beta_factor: 0.0018
# Epoch 17 - Train Loss: 48.5425
# Sub-losses: recon_loss: 48.1384, var_loss: 0.4041, anneal_factor: 0.0266, effective_beta_factor: 0.0027
# Epoch 17 - Valid Loss: 27.8762
# Sub-losses: recon_loss: 27.5086, var_loss: 0.3676, anneal_factor: 0.0266, effective_beta_factor: 0.0027
# Epoch 18 - Train Loss: 48.3160
# Sub-losses: recon_loss: 47.6874, var_loss: 0.6286, anneal_factor: 0.0392, effective_beta_factor: 0.0039
# Epoch 18 - Valid Loss: 25.8650
# Sub-losses: recon_loss: 25.2916, var_loss: 0.5734, anneal_factor: 0.0392, effective_beta_factor: 0.0039
# Epoch 19 - Train Loss: 47.7019
# Sub-losses: recon_loss: 46.7457, var_loss: 0.9562, anneal_factor: 0.0573, effective_beta_factor: 0.0057
# Epoch 19 - Valid Loss: 26.7218
# Sub-losses: recon_loss: 25.8462, var_loss: 0.8756, anneal_factor: 0.0573, effective_beta_factor: 0.0057
# Epoch 20 - Train Loss: 48.3424
# Sub-losses: recon_loss: 46.9289, var_loss: 1.4134, anneal_factor: 0.0832, effective_beta_factor: 0.0083
# Epoch 20 - Valid Loss: 26.7383
# Sub-losses: recon_loss: 25.5374, var_loss: 1.2008, anneal_factor: 0.0832, effective_beta_factor: 0.0083
# Epoch 21 - Train Loss: 47.5927
# Sub-losses: recon_loss: 45.5565, var_loss: 2.0363, anneal_factor: 0.1192, effective_beta_factor: 0.0119
# Epoch 21 - Valid Loss: 26.3332
# Sub-losses: recon_loss: 24.4878, var_loss: 1.8454, anneal_factor: 0.1192, effective_beta_factor: 0.0119
# Epoch 22 - Train Loss: 47.9019
# Sub-losses: recon_loss: 45.1088, var_loss: 2.7931, anneal_factor: 0.1680, effective_beta_factor: 0.0168
# Epoch 22 - Valid Loss: 26.9557
# Sub-losses: recon_loss: 24.5875, var_loss: 2.3682, anneal_factor: 0.1680, effective_beta_factor: 0.0168
# Epoch 23 - Train Loss: 47.8575
# Sub-losses: recon_loss: 44.1769, var_loss: 3.6806, anneal_factor: 0.2315, effective_beta_factor: 0.0231
# Epoch 23 - Valid Loss: 27.4580
# Sub-losses: recon_loss: 24.3068, var_loss: 3.1512, anneal_factor: 0.2315, effective_beta_factor: 0.0231
# Epoch 24 - Train Loss: 48.3847
# Sub-losses: recon_loss: 43.8104, var_loss: 4.5743, anneal_factor: 0.3100, effective_beta_factor: 0.0310
# Epoch 24 - Valid Loss: 27.3309
# Sub-losses: recon_loss: 23.2925, var_loss: 4.0385, anneal_factor: 0.3100, effective_beta_factor: 0.0310
# Epoch 25 - Train Loss: 48.9639
# Sub-losses: recon_loss: 43.6269, var_loss: 5.3370, anneal_factor: 0.4013, effective_beta_factor: 0.0401
# Epoch 25 - Valid Loss: 27.2297
# Sub-losses: recon_loss: 22.7616, var_loss: 4.4681, anneal_factor: 0.4013, effective_beta_factor: 0.0401
# Epoch 26 - Train Loss: 49.7655
# Sub-losses: recon_loss: 43.8122, var_loss: 5.9534, anneal_factor: 0.5000, effective_beta_factor: 0.0500
# Epoch 26 - Valid Loss: 28.4310
# Sub-losses: recon_loss: 23.3723, var_loss: 5.0587, anneal_factor: 0.5000, effective_beta_factor: 0.0500
# Epoch 27 - Train Loss: 49.1355
# Sub-losses: recon_loss: 42.8517, var_loss: 6.2838, anneal_factor: 0.5987, effective_beta_factor: 0.0599
# Epoch 27 - Valid Loss: 29.4100
# Sub-losses: recon_loss: 23.9081, var_loss: 5.5020, anneal_factor: 0.5987, effective_beta_factor: 0.0599
# Epoch 28 - Train Loss: 49.9218
# Sub-losses: recon_loss: 43.4796, var_loss: 6.4422, anneal_factor: 0.6900, effective_beta_factor: 0.0690
# Epoch 28 - Valid Loss: 28.5573
# Sub-losses: recon_loss: 23.0804, var_loss: 5.4769, anneal_factor: 0.6900, effective_beta_factor: 0.0690
# Epoch 29 - Train Loss: 50.1184
# Sub-losses: recon_loss: 43.6288, var_loss: 6.4897, anneal_factor: 0.7685, effective_beta_factor: 0.0769
# Epoch 29 - Valid Loss: 30.0238
# Sub-losses: recon_loss: 24.2316, var_loss: 5.7922, anneal_factor: 0.7685, effective_beta_factor: 0.0769
# Epoch 30 - Train Loss: 49.5597
# Sub-losses: recon_loss: 43.1762, var_loss: 6.3835, anneal_factor: 0.8320, effective_beta_factor: 0.0832
# Epoch 30 - Valid Loss: 27.9909
# Sub-losses: recon_loss: 22.5646, var_loss: 5.4262, anneal_factor: 0.8320, effective_beta_factor: 0.0832
# Epoch 31 - Train Loss: 50.3343
# Sub-losses: recon_loss: 44.1250, var_loss: 6.2093, anneal_factor: 0.8808, effective_beta_factor: 0.0881
# Epoch 31 - Valid Loss: 28.9674
# Sub-losses: recon_loss: 23.4580, var_loss: 5.5093, anneal_factor: 0.8808, effective_beta_factor: 0.0881
# Epoch 32 - Train Loss: 49.6179
# Sub-losses: recon_loss: 43.4663, var_loss: 6.1516, anneal_factor: 0.9168, effective_beta_factor: 0.0917
# Epoch 32 - Valid Loss: 29.2952
# Sub-losses: recon_loss: 23.7435, var_loss: 5.5517, anneal_factor: 0.9168, effective_beta_factor: 0.0917
# Epoch 33 - Train Loss: 49.2408
# Sub-losses: recon_loss: 43.1334, var_loss: 6.1074, anneal_factor: 0.9427, effective_beta_factor: 0.0943
# Epoch 33 - Valid Loss: 28.0754
# Sub-losses: recon_loss: 22.9388, var_loss: 5.1366, anneal_factor: 0.9427, effective_beta_factor: 0.0943
# Epoch 34 - Train Loss: 50.0608
# Sub-losses: recon_loss: 44.0367, var_loss: 6.0242, anneal_factor: 0.9608, effective_beta_factor: 0.0961
# Epoch 34 - Valid Loss: 28.2500
# Sub-losses: recon_loss: 23.0900, var_loss: 5.1600, anneal_factor: 0.9608, effective_beta_factor: 0.0961
# Epoch 35 - Train Loss: 48.0960
# Sub-losses: recon_loss: 42.1793, var_loss: 5.9168, anneal_factor: 0.9734, effective_beta_factor: 0.0973
# Epoch 35 - Valid Loss: 27.9681
# Sub-losses: recon_loss: 22.9061, var_loss: 5.0620, anneal_factor: 0.9734, effective_beta_factor: 0.0973
# Epoch 36 - Train Loss: 49.9334
# Sub-losses: recon_loss: 44.0998, var_loss: 5.8335, anneal_factor: 0.9820, effective_beta_factor: 0.0982
# Epoch 36 - Valid Loss: 28.8236
# Sub-losses: recon_loss: 23.6877, var_loss: 5.1359, anneal_factor: 0.9820, effective_beta_factor: 0.0982
# Epoch 37 - Train Loss: 47.8241
# Sub-losses: recon_loss: 42.0169, var_loss: 5.8072, anneal_factor: 0.9879, effective_beta_factor: 0.0988
# Epoch 37 - Valid Loss: 28.7095
# Sub-losses: recon_loss: 23.2314, var_loss: 5.4781, anneal_factor: 0.9879, effective_beta_factor: 0.0988
# Epoch 38 - Train Loss: 48.8286
# Sub-losses: recon_loss: 43.1514, var_loss: 5.6773, anneal_factor: 0.9918, effective_beta_factor: 0.0992
# Epoch 38 - Valid Loss: 27.2716
# Sub-losses: recon_loss: 22.1583, var_loss: 5.1133, anneal_factor: 0.9918, effective_beta_factor: 0.0992
# Epoch 39 - Train Loss: 47.7191
# Sub-losses: recon_loss: 42.1045, var_loss: 5.6146, anneal_factor: 0.9945, effective_beta_factor: 0.0995
# Epoch 39 - Valid Loss: 28.7225
# Sub-losses: recon_loss: 23.7693, var_loss: 4.9531, anneal_factor: 0.9945, effective_beta_factor: 0.0995
# Epoch 40 - Train Loss: 46.8724
# Sub-losses: recon_loss: 41.1874, var_loss: 5.6850, anneal_factor: 0.9963, effective_beta_factor: 0.0996
# Epoch 40 - Valid Loss: 27.6762
# Sub-losses: recon_loss: 22.7184, var_loss: 4.9578, anneal_factor: 0.9963, effective_beta_factor: 0.0996
# Epoch 41 - Train Loss: 47.1506
# Sub-losses: recon_loss: 41.5269, var_loss: 5.6236, anneal_factor: 0.9975, effective_beta_factor: 0.0998
# Epoch 41 - Valid Loss: 27.6010
# Sub-losses: recon_loss: 22.4094, var_loss: 5.1916, anneal_factor: 0.9975, effective_beta_factor: 0.0998
# Epoch 42 - Train Loss: 47.1986
# Sub-losses: recon_loss: 41.6136, var_loss: 5.5850, anneal_factor: 0.9983, effective_beta_factor: 0.0998
# Epoch 42 - Valid Loss: 27.4744
# Sub-losses: recon_loss: 22.3566, var_loss: 5.1178, anneal_factor: 0.9983, effective_beta_factor: 0.0998
# Epoch 43 - Train Loss: 47.7378
# Sub-losses: recon_loss: 42.1438, var_loss: 5.5940, anneal_factor: 0.9989, effective_beta_factor: 0.0999
# Epoch 43 - Valid Loss: 28.3221
# Sub-losses: recon_loss: 23.3823, var_loss: 4.9398, anneal_factor: 0.9989, effective_beta_factor: 0.0999
# Epoch 44 - Train Loss: 45.9287
# Sub-losses: recon_loss: 40.3805, var_loss: 5.5482, anneal_factor: 0.9993, effective_beta_factor: 0.0999
# Epoch 44 - Valid Loss: 26.5889
# Sub-losses: recon_loss: 21.6521, var_loss: 4.9368, anneal_factor: 0.9993, effective_beta_factor: 0.0999
# Epoch 45 - Train Loss: 46.4840
# Sub-losses: recon_loss: 40.9491, var_loss: 5.5350, anneal_factor: 0.9995, effective_beta_factor: 0.0999
# Epoch 45 - Valid Loss: 27.2074
# Sub-losses: recon_loss: 22.0111, var_loss: 5.1963, anneal_factor: 0.9995, effective_beta_factor: 0.0999
# Epoch 46 - Train Loss: 47.2484
# Sub-losses: recon_loss: 41.7877, var_loss: 5.4606, anneal_factor: 0.9997, effective_beta_factor: 0.1000
# Epoch 46 - Valid Loss: 27.2788
# Sub-losses: recon_loss: 22.4267, var_loss: 4.8521, anneal_factor: 0.9997, effective_beta_factor: 0.1000
# Epoch 47 - Train Loss: 46.9022
# Sub-losses: recon_loss: 41.4438, var_loss: 5.4585, anneal_factor: 0.9998, effective_beta_factor: 0.1000
# Epoch 47 - Valid Loss: 27.0758
# Sub-losses: recon_loss: 22.3981, var_loss: 4.6777, anneal_factor: 0.9998, effective_beta_factor: 0.1000
# Epoch 48 - Train Loss: 46.3661
# Sub-losses: recon_loss: 40.9153, var_loss: 5.4507, anneal_factor: 0.9998, effective_beta_factor: 0.1000
# Epoch 48 - Valid Loss: 27.4188
# Sub-losses: recon_loss: 22.4701, var_loss: 4.9486, anneal_factor: 0.9998, effective_beta_factor: 0.1000
# Epoch 49 - Train Loss: 45.8264
# Sub-losses: recon_loss: 40.4750, var_loss: 5.3514, anneal_factor: 0.9999, effective_beta_factor: 0.1000
# Epoch 49 - Valid Loss: 26.8123
# Sub-losses: recon_loss: 22.1293, var_loss: 4.6830, anneal_factor: 0.9999, effective_beta_factor: 0.1000
# Epoch 50 - Train Loss: 45.7725
# Sub-losses: recon_loss: 40.3896, var_loss: 5.3829, anneal_factor: 0.9999, effective_beta_factor: 0.1000
# Epoch 50 - Valid Loss: 26.9479
# Sub-losses: recon_loss: 22.1816, var_loss: 4.7663, anneal_factor: 0.9999, effective_beta_factor: 0.1000
# Epoch 1 - Train Loss: 736.8073
# Sub-losses: recon_loss: 736.8072, var_loss: 0.0001, anneal_factor: 0.0000, effective_beta_factor: 0.0000
# Epoch 1 - Valid Loss: 675.6695
# Sub-losses: recon_loss: 675.6692, var_loss: 0.0002, anneal_factor: 0.0000, effective_beta_factor: 0.0000
# Epoch 2 - Train Loss: 668.5357
# Sub-losses: recon_loss: 668.5347, var_loss: 0.0010, anneal_factor: 0.0001, effective_beta_factor: 0.0000
# Epoch 2 - Valid Loss: 661.0749
# Sub-losses: recon_loss: 661.0742, var_loss: 0.0007, anneal_factor: 0.0001, effective_beta_factor: 0.0000
# Epoch 3 - Train Loss: 646.0902
# Sub-losses: recon_loss: 646.0890, var_loss: 0.0012, anneal_factor: 0.0001, effective_beta_factor: 0.0000
# Epoch 3 - Valid Loss: 634.7931
# Sub-losses: recon_loss: 634.7926, var_loss: 0.0005, anneal_factor: 0.0001, effective_beta_factor: 0.0000
# Epoch 4 - Train Loss: 636.2532
# Sub-losses: recon_loss: 636.2523, var_loss: 0.0010, anneal_factor: 0.0002, effective_beta_factor: 0.0000
# Epoch 4 - Valid Loss: 626.3016
# Sub-losses: recon_loss: 626.3009, var_loss: 0.0007, anneal_factor: 0.0002, effective_beta_factor: 0.0000
# Epoch 5 - Train Loss: 628.3123
# Sub-losses: recon_loss: 628.3109, var_loss: 0.0013, anneal_factor: 0.0002, effective_beta_factor: 0.0000
# Epoch 5 - Valid Loss: 618.3783
# Sub-losses: recon_loss: 618.3774, var_loss: 0.0010, anneal_factor: 0.0002, effective_beta_factor: 0.0000
# Epoch 6 - Train Loss: 622.3807
# Sub-losses: recon_loss: 622.3784, var_loss: 0.0023, anneal_factor: 0.0003, effective_beta_factor: 0.0000
# Epoch 6 - Valid Loss: 612.0027
# Sub-losses: recon_loss: 612.0009, var_loss: 0.0019, anneal_factor: 0.0003, effective_beta_factor: 0.0000
# Epoch 7 - Train Loss: 618.1140
# Sub-losses: recon_loss: 618.1098, var_loss: 0.0043, anneal_factor: 0.0005, effective_beta_factor: 0.0001
# Epoch 7 - Valid Loss: 606.9306
# Sub-losses: recon_loss: 606.9277, var_loss: 0.0029, anneal_factor: 0.0005, effective_beta_factor: 0.0001
# Epoch 8 - Train Loss: 612.3314
# Sub-losses: recon_loss: 612.3265, var_loss: 0.0049, anneal_factor: 0.0007, effective_beta_factor: 0.0001
# Epoch 8 - Valid Loss: 600.0418
# Sub-losses: recon_loss: 600.0375, var_loss: 0.0043, anneal_factor: 0.0007, effective_beta_factor: 0.0001
# Epoch 9 - Train Loss: 606.0011
# Sub-losses: recon_loss: 605.9938, var_loss: 0.0073, anneal_factor: 0.0011, effective_beta_factor: 0.0001
# Epoch 9 - Valid Loss: 593.0553
# Sub-losses: recon_loss: 593.0475, var_loss: 0.0078, anneal_factor: 0.0011, effective_beta_factor: 0.0001
# Epoch 10 - Train Loss: 599.4145
# Sub-losses: recon_loss: 599.4025, var_loss: 0.0120, anneal_factor: 0.0017, effective_beta_factor: 0.0002
# Epoch 10 - Valid Loss: 587.8982
# Sub-losses: recon_loss: 587.8856, var_loss: 0.0126, anneal_factor: 0.0017, effective_beta_factor: 0.0002
# Epoch 11 - Train Loss: 596.5645
# Sub-losses: recon_loss: 596.5442, var_loss: 0.0203, anneal_factor: 0.0025, effective_beta_factor: 0.0002
# Epoch 11 - Valid Loss: 582.1874
# Sub-losses: recon_loss: 582.1672, var_loss: 0.0202, anneal_factor: 0.0025, effective_beta_factor: 0.0002
# Epoch 12 - Train Loss: 591.6636
# Sub-losses: recon_loss: 591.6286, var_loss: 0.0350, anneal_factor: 0.0037, effective_beta_factor: 0.0004
# Epoch 12 - Valid Loss: 578.1370
# Sub-losses: recon_loss: 578.1018, var_loss: 0.0352, anneal_factor: 0.0037, effective_beta_factor: 0.0004
# Epoch 13 - Train Loss: 587.3842
# Sub-losses: recon_loss: 587.3260, var_loss: 0.0582, anneal_factor: 0.0055, effective_beta_factor: 0.0005
# Epoch 13 - Valid Loss: 576.9645
# Sub-losses: recon_loss: 576.9051, var_loss: 0.0594, anneal_factor: 0.0055, effective_beta_factor: 0.0005
# Epoch 14 - Train Loss: 585.8600
# Sub-losses: recon_loss: 585.7641, var_loss: 0.0959, anneal_factor: 0.0082, effective_beta_factor: 0.0008
# Epoch 14 - Valid Loss: 575.7695
# Sub-losses: recon_loss: 575.6712, var_loss: 0.0982, anneal_factor: 0.0082, effective_beta_factor: 0.0008
# Epoch 15 - Train Loss: 582.8586
# Sub-losses: recon_loss: 582.7020, var_loss: 0.1566, anneal_factor: 0.0121, effective_beta_factor: 0.0012
# Epoch 15 - Valid Loss: 572.9565
# Sub-losses: recon_loss: 572.7922, var_loss: 0.1643, anneal_factor: 0.0121, effective_beta_factor: 0.0012
# Epoch 16 - Train Loss: 581.8946
# Sub-losses: recon_loss: 581.6466, var_loss: 0.2480, anneal_factor: 0.0180, effective_beta_factor: 0.0018
# Epoch 16 - Valid Loss: 572.4658
# Sub-losses: recon_loss: 572.2192, var_loss: 0.2466, anneal_factor: 0.0180, effective_beta_factor: 0.0018
# Epoch 17 - Train Loss: 579.4398
# Sub-losses: recon_loss: 579.0468, var_loss: 0.3929, anneal_factor: 0.0266, effective_beta_factor: 0.0027
# Epoch 17 - Valid Loss: 571.0847
# Sub-losses: recon_loss: 570.6952, var_loss: 0.3895, anneal_factor: 0.0266, effective_beta_factor: 0.0027
# Epoch 18 - Train Loss: 578.1213
# Sub-losses: recon_loss: 577.5016, var_loss: 0.6197, anneal_factor: 0.0392, effective_beta_factor: 0.0039
# Epoch 18 - Valid Loss: 569.9892
# Sub-losses: recon_loss: 569.4158, var_loss: 0.5734, anneal_factor: 0.0392, effective_beta_factor: 0.0039
# Epoch 19 - Train Loss: 578.7047
# Sub-losses: recon_loss: 577.7578, var_loss: 0.9469, anneal_factor: 0.0573, effective_beta_factor: 0.0057
# Epoch 19 - Valid Loss: 569.8652
# Sub-losses: recon_loss: 568.9810, var_loss: 0.8842, anneal_factor: 0.0573, effective_beta_factor: 0.0057
# Epoch 20 - Train Loss: 576.5113
# Sub-losses: recon_loss: 575.1122, var_loss: 1.3990, anneal_factor: 0.0832, effective_beta_factor: 0.0083
# Epoch 20 - Valid Loss: 569.0398
# Sub-losses: recon_loss: 567.6482, var_loss: 1.3917, anneal_factor: 0.0832, effective_beta_factor: 0.0083
# Epoch 21 - Train Loss: 577.2454
# Sub-losses: recon_loss: 575.2375, var_loss: 2.0079, anneal_factor: 0.1192, effective_beta_factor: 0.0119
# Epoch 21 - Valid Loss: 567.5842
# Sub-losses: recon_loss: 565.7685, var_loss: 1.8157, anneal_factor: 0.1192, effective_beta_factor: 0.0119
# Epoch 22 - Train Loss: 577.1612
# Sub-losses: recon_loss: 574.3566, var_loss: 2.8046, anneal_factor: 0.1680, effective_beta_factor: 0.0168
# Epoch 22 - Valid Loss: 567.5335
# Sub-losses: recon_loss: 564.7986, var_loss: 2.7349, anneal_factor: 0.1680, effective_beta_factor: 0.0168
# Epoch 23 - Train Loss: 576.2471
# Sub-losses: recon_loss: 572.5451, var_loss: 3.7020, anneal_factor: 0.2315, effective_beta_factor: 0.0231
# Epoch 23 - Valid Loss: 567.1500
# Sub-losses: recon_loss: 563.7385, var_loss: 3.4115, anneal_factor: 0.2315, effective_beta_factor: 0.0231
# Epoch 24 - Train Loss: 576.5811
# Sub-losses: recon_loss: 572.0163, var_loss: 4.5647, anneal_factor: 0.3100, effective_beta_factor: 0.0310
# Epoch 24 - Valid Loss: 567.3348
# Sub-losses: recon_loss: 562.9664, var_loss: 4.3684, anneal_factor: 0.3100, effective_beta_factor: 0.0310
# Epoch 25 - Train Loss: 575.8959
# Sub-losses: recon_loss: 570.5614, var_loss: 5.3345, anneal_factor: 0.4013, effective_beta_factor: 0.0401
# Epoch 25 - Valid Loss: 568.3411
# Sub-losses: recon_loss: 563.7884, var_loss: 4.5527, anneal_factor: 0.4013, effective_beta_factor: 0.0401
# Epoch 26 - Train Loss: 577.1100
# Sub-losses: recon_loss: 571.2138, var_loss: 5.8962, anneal_factor: 0.5000, effective_beta_factor: 0.0500
# Epoch 26 - Valid Loss: 567.4926
# Sub-losses: recon_loss: 562.0059, var_loss: 5.4867, anneal_factor: 0.5000, effective_beta_factor: 0.0500
# Epoch 27 - Train Loss: 576.2027
# Sub-losses: recon_loss: 569.9114, var_loss: 6.2913, anneal_factor: 0.5987, effective_beta_factor: 0.0599
# Epoch 27 - Valid Loss: 568.5122
# Sub-losses: recon_loss: 562.7581, var_loss: 5.7541, anneal_factor: 0.5987, effective_beta_factor: 0.0599
# Epoch 28 - Train Loss: 574.8890
# Sub-losses: recon_loss: 568.4615, var_loss: 6.4275, anneal_factor: 0.6900, effective_beta_factor: 0.0690
# Epoch 28 - Valid Loss: 566.4355
# Sub-losses: recon_loss: 560.4729, var_loss: 5.9626, anneal_factor: 0.6900, effective_beta_factor: 0.0690
# Epoch 29 - Train Loss: 575.8463
# Sub-losses: recon_loss: 569.3454, var_loss: 6.5010, anneal_factor: 0.7685, effective_beta_factor: 0.0769
# Epoch 29 - Valid Loss: 565.9877
# Sub-losses: recon_loss: 560.6294, var_loss: 5.3583, anneal_factor: 0.7685, effective_beta_factor: 0.0769
# Epoch 30 - Train Loss: 575.9241
# Sub-losses: recon_loss: 569.4999, var_loss: 6.4242, anneal_factor: 0.8320, effective_beta_factor: 0.0832
# Epoch 30 - Valid Loss: 565.0371
# Sub-losses: recon_loss: 559.6118, var_loss: 5.4252, anneal_factor: 0.8320, effective_beta_factor: 0.0832
# Epoch 31 - Train Loss: 573.0807
# Sub-losses: recon_loss: 566.7216, var_loss: 6.3592, anneal_factor: 0.8808, effective_beta_factor: 0.0881
# Epoch 31 - Valid Loss: 563.7169
# Sub-losses: recon_loss: 557.7395, var_loss: 5.9774, anneal_factor: 0.8808, effective_beta_factor: 0.0881
# Epoch 32 - Train Loss: 572.5607
# Sub-losses: recon_loss: 566.2643, var_loss: 6.2965, anneal_factor: 0.9168, effective_beta_factor: 0.0917
# Epoch 32 - Valid Loss: 561.7096
# Sub-losses: recon_loss: 555.8484, var_loss: 5.8612, anneal_factor: 0.9168, effective_beta_factor: 0.0917
# Epoch 33 - Train Loss: 572.5469
# Sub-losses: recon_loss: 566.3607, var_loss: 6.1862, anneal_factor: 0.9427, effective_beta_factor: 0.0943
# Epoch 33 - Valid Loss: 560.9609
# Sub-losses: recon_loss: 555.3490, var_loss: 5.6119, anneal_factor: 0.9427, effective_beta_factor: 0.0943
# Epoch 34 - Train Loss: 569.5699
# Sub-losses: recon_loss: 563.4305, var_loss: 6.1394, anneal_factor: 0.9608, effective_beta_factor: 0.0961
# Epoch 34 - Valid Loss: 558.8875
# Sub-losses: recon_loss: 553.5809, var_loss: 5.3065, anneal_factor: 0.9608, effective_beta_factor: 0.0961
# Epoch 35 - Train Loss: 569.5026
# Sub-losses: recon_loss: 563.4070, var_loss: 6.0957, anneal_factor: 0.9734, effective_beta_factor: 0.0973
# Epoch 35 - Valid Loss: 558.8076
# Sub-losses: recon_loss: 553.1236, var_loss: 5.6840, anneal_factor: 0.9734, effective_beta_factor: 0.0973
# Epoch 36 - Train Loss: 568.4430
# Sub-losses: recon_loss: 562.4682, var_loss: 5.9748, anneal_factor: 0.9820, effective_beta_factor: 0.0982
# Epoch 36 - Valid Loss: 557.8060
# Sub-losses: recon_loss: 552.0395, var_loss: 5.7665, anneal_factor: 0.9820, effective_beta_factor: 0.0982
# Epoch 37 - Train Loss: 566.9846
# Sub-losses: recon_loss: 560.9682, var_loss: 6.0164, anneal_factor: 0.9879, effective_beta_factor: 0.0988
# Epoch 37 - Valid Loss: 556.1316
# Sub-losses: recon_loss: 550.3443, var_loss: 5.7873, anneal_factor: 0.9879, effective_beta_factor: 0.0988
# Epoch 38 - Train Loss: 567.5317
# Sub-losses: recon_loss: 561.6024, var_loss: 5.9292, anneal_factor: 0.9918, effective_beta_factor: 0.0992
# Epoch 38 - Valid Loss: 556.9118
# Sub-losses: recon_loss: 551.6125, var_loss: 5.2993, anneal_factor: 0.9918, effective_beta_factor: 0.0992
# Epoch 39 - Train Loss: 565.8946
# Sub-losses: recon_loss: 559.9741, var_loss: 5.9205, anneal_factor: 0.9945, effective_beta_factor: 0.0995
# Epoch 39 - Valid Loss: 554.9965
# Sub-losses: recon_loss: 549.8417, var_loss: 5.1548, anneal_factor: 0.9945, effective_beta_factor: 0.0995
# Epoch 40 - Train Loss: 565.3198
# Sub-losses: recon_loss: 559.3939, var_loss: 5.9258, anneal_factor: 0.9963, effective_beta_factor: 0.0996
# Epoch 40 - Valid Loss: 554.5279
# Sub-losses: recon_loss: 549.5121, var_loss: 5.0159, anneal_factor: 0.9963, effective_beta_factor: 0.0996
# Epoch 41 - Train Loss: 564.6501
# Sub-losses: recon_loss: 558.6211, var_loss: 6.0290, anneal_factor: 0.9975, effective_beta_factor: 0.0998
# Epoch 41 - Valid Loss: 553.3329
# Sub-losses: recon_loss: 548.1399, var_loss: 5.1930, anneal_factor: 0.9975, effective_beta_factor: 0.0998
# Epoch 42 - Train Loss: 563.0034
# Sub-losses: recon_loss: 557.0209, var_loss: 5.9825, anneal_factor: 0.9983, effective_beta_factor: 0.0998
# Epoch 42 - Valid Loss: 552.3522
# Sub-losses: recon_loss: 547.1399, var_loss: 5.2123, anneal_factor: 0.9983, effective_beta_factor: 0.0998
# Epoch 43 - Train Loss: 564.2179
# Sub-losses: recon_loss: 558.2351, var_loss: 5.9828, anneal_factor: 0.9989, effective_beta_factor: 0.0999
# Epoch 43 - Valid Loss: 551.9561
# Sub-losses: recon_loss: 546.1482, var_loss: 5.8080, anneal_factor: 0.9989, effective_beta_factor: 0.0999
# Epoch 44 - Train Loss: 563.2833
# Sub-losses: recon_loss: 557.3796, var_loss: 5.9037, anneal_factor: 0.9993, effective_beta_factor: 0.0999
# Epoch 44 - Valid Loss: 551.8361
# Sub-losses: recon_loss: 546.4230, var_loss: 5.4131, anneal_factor: 0.9993, effective_beta_factor: 0.0999
# Epoch 45 - Train Loss: 561.9332
# Sub-losses: recon_loss: 556.0142, var_loss: 5.9190, anneal_factor: 0.9995, effective_beta_factor: 0.0999
# Epoch 45 - Valid Loss: 550.7352
# Sub-losses: recon_loss: 545.4021, var_loss: 5.3331, anneal_factor: 0.9995, effective_beta_factor: 0.0999
# Epoch 46 - Train Loss: 561.2107
# Sub-losses: recon_loss: 555.3103, var_loss: 5.9003, anneal_factor: 0.9997, effective_beta_factor: 0.1000
# Epoch 46 - Valid Loss: 550.1712
# Sub-losses: recon_loss: 544.6060, var_loss: 5.5652, anneal_factor: 0.9997, effective_beta_factor: 0.1000
# Epoch 47 - Train Loss: 561.3766
# Sub-losses: recon_loss: 555.4520, var_loss: 5.9246, anneal_factor: 0.9998, effective_beta_factor: 0.1000
# Epoch 47 - Valid Loss: 550.2418
# Sub-losses: recon_loss: 544.5509, var_loss: 5.6908, anneal_factor: 0.9998, effective_beta_factor: 0.1000
# Epoch 48 - Train Loss: 560.3664
# Sub-losses: recon_loss: 554.3431, var_loss: 6.0233, anneal_factor: 0.9998, effective_beta_factor: 0.1000
# Epoch 48 - Valid Loss: 548.4972
# Sub-losses: recon_loss: 542.7988, var_loss: 5.6983, anneal_factor: 0.9998, effective_beta_factor: 0.1000
# Epoch 49 - Train Loss: 559.2185
# Sub-losses: recon_loss: 553.2284, var_loss: 5.9901, anneal_factor: 0.9999, effective_beta_factor: 0.1000
# Epoch 49 - Valid Loss: 548.8594
# Sub-losses: recon_loss: 543.6195, var_loss: 5.2398, anneal_factor: 0.9999, effective_beta_factor: 0.1000
# Epoch 50 - Train Loss: 558.1347
# Sub-losses: recon_loss: 552.1198, var_loss: 6.0149, anneal_factor: 0.9999, effective_beta_factor: 0.1000
# Epoch 50 - Valid Loss: 547.2715
# Sub-losses: recon_loss: 541.6543, var_loss: 5.6172, anneal_factor: 0.9999, effective_beta_factor: 0.1000

# %%
varix_imputed._datasets.train.metadata
# Out:
#                                             barcode    assigned_cluster  \
# human1_lib1.final_cell_0001_0   GATGACGGAC-GGTGGGAT              acinar
# human1_lib1.final_cell_0002_0   GAGCGTTGCT-ACCTTCTT              acinar
# human1_lib1.final_cell_0004_0   GATGTACACG-TTAAACTG              acinar
# human1_lib1.final_cell_0005_0   GAGATTGCGA-GTCGTCGT              acinar
# human1_lib1.final_cell_0008_0   GACTCTTGAC-AAACTGGT              acinar
# ...                                             ...                 ...
# human4_lib3.final_cell_0697_3   GAGATCTCGG-GTCTCTCT  activated_stellate
# human4_lib3.final_cell_0698_3     GCTTACCT-ATGTTGGC               alpha
# human4_lib3.final_cell_0699_3  TGACACAGTTT-TTGTCGCC                beta
# human4_lib3.final_cell_0700_3   GACGACTCCT-CGCTAATA                beta
# human4_lib3.final_cell_0701_3     TGATGCCC-TTGCACGC              ductal
#
#                               sample_id  n_genes
# human1_lib1.final_cell_0001_0    human1     3526
# human1_lib1.final_cell_0002_0    human1     4201
# human1_lib1.final_cell_0004_0    human1     2956
# human1_lib1.final_cell_0005_0    human1     2715
# human1_lib1.final_cell_0008_0    human1     2656
# ...                                 ...      ...
# human4_lib3.final_cell_0697_3    human4     1055
# human4_lib3.final_cell_0698_3    human4     1007
# human4_lib3.final_cell_0699_3    human4      942
# human4_lib3.final_cell_0700_3    human4     1031
# human4_lib3.final_cell_0701_3    human4      985
#
# [5998 rows x 4 columns]

# %%
varix_imputed.show_result()
# Out:
# Creating plots ...

# %%
varix_imputed.show_result()
# Out:
# Creating plots ...

# %%
varix_imputed.evaluate()
# Out:
# Perform ML task with feature df: Latent
# Latent
# Perform ML task for target parameter: assigned_cluster
# /Users/maximilianjoas/development/autoencodix_package/.venv/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Result Object Public Attributes:
# ------------------------------
# latentspaces: TrainingDynamics object
# sample_ids: TrainingDynamics object
# reconstructions: TrainingDynamics object
# mus: TrainingDynamics object
# sigmas: TrainingDynamics object
# losses: TrainingDynamics object
# sub_losses: LossRegistry(_losses={'recon_loss': TrainingDynamics(), 'var_loss': TrainingDynamics(), 'anneal_factor': TrainingDynamics(), 'effective_beta_factor': TrainingDynamics()})
# preprocessed_data: Tensor of shape (0,)
# model: VarixArchitecture
# model_checkpoints: TrainingDynamics object
# datasets: DatasetContainer(train=<autoencodix.data._numeric_dataset.NumericDataset object at 0x36b2aa710>, valid=<autoencodix.data._numeric_dataset.NumericDataset object at 0x36b2aae30>, test=<autoencodix.data._numeric_dataset.NumericDataset object at 0x36b2a8d00>)
# new_datasets: DatasetContainer(train=None, valid=None, test=None)
# adata_latent: AnnData object with n_obs × n_vars = 1715 × 16
#     uns: 'var_names'
# final_reconstruction: None
# sub_results: None
# sub_reconstructions: None
# embedding_evaluation:   score_split      CLINIC_PARAM       metric     value                ML_ALG  \
# 0       train  assigned_cluster  roc_auc_ovo  0.891374  LogisticRegression()
# 1       valid  assigned_cluster  roc_auc_ovo  0.838014  LogisticRegression()
# 2        test  assigned_cluster  roc_auc_ovo  0.906598  LogisticRegression()
#
#           ML_TYPE ML_TASK ML_SUBTASK
# 0  classification  Latent     Latent
# 1  classification  Latent     Latent
# 2  classification  Latent     Latent

# %%
varix_missing.evaluate()
# Out:
# Perform ML task with feature df: Latent
# Latent
# Perform ML task for target parameter: assigned_cluster
# /Users/maximilianjoas/development/autoencodix_package/.venv/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/maximilianjoas/development/autoencodix_package/.venv/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Perform ML task with feature df: Latent
# Latent
# Perform ML task for target parameter: assigned_cluster
# Result Object Public Attributes:
# ------------------------------
# latentspaces: TrainingDynamics object
# sample_ids: TrainingDynamics object
# reconstructions: TrainingDynamics object
# mus: TrainingDynamics object
# sigmas: TrainingDynamics object
# losses: TrainingDynamics object
# sub_losses: LossRegistry(_losses={'recon_loss': TrainingDynamics(), 'var_loss': TrainingDynamics(), 'anneal_factor': TrainingDynamics(), 'effective_beta_factor': TrainingDynamics()})
# preprocessed_data: Tensor of shape (0,)
# model: VarixArchitecture
# model_checkpoints: TrainingDynamics object
# datasets: DatasetContainer(train=<autoencodix.data._numeric_dataset.NumericDataset object at 0x36b2c4c70>, valid=<autoencodix.data._numeric_dataset.NumericDataset object at 0x36b2c49d0>, test=<autoencodix.data._numeric_dataset.NumericDataset object at 0x36b2c4490>)
# new_datasets: DatasetContainer(train=None, valid=None, test=None)
# adata_latent: AnnData object with n_obs × n_vars = 1715 × 16
#     uns: 'var_names'
# final_reconstruction: None
# sub_results: None
# sub_reconstructions: None
# embedding_evaluation:   score_split      CLINIC_PARAM       metric     value                ML_ALG  \
# 0       train  assigned_cluster  roc_auc_ovo  0.899773  LogisticRegression()
# 1       valid  assigned_cluster  roc_auc_ovo  0.890319  LogisticRegression()
# 2        test  assigned_cluster  roc_auc_ovo  0.899939  LogisticRegression()
# 0       train  assigned_cluster  roc_auc_ovo  0.899773  LogisticRegression()
# 1       valid  assigned_cluster  roc_auc_ovo  0.890319  LogisticRegression()
# 2        test  assigned_cluster  roc_auc_ovo  0.899939  LogisticRegression()
#
#           ML_TYPE ML_TASK ML_SUBTASK
# 0  classification  Latent     Latent
# 1  classification  Latent     Latent
# 2  classification  Latent     Latent
# 0  classification  Latent     Latent
# 1  classification  Latent     Latent
# 2  classification  Latent     Latent

# %% [markdown]
# ## 7) Save, Load and Re-Use Maskix
#
# There are not `Maskix` specific steps here. See the `Tutorials/PipelineTutorials/Vanillix.ipynb
# `  or `Tutorials/DeepDives/MemoryEfficientSaving.ipynb` for details. Below is a basic save/load usecase:

# %%
import os
import glob
# use a filename without extension, we handle this internally
outpath = os.path.join("tutorial_res", "maskix")
maskix.save(file_path=outpath, save_all=False)

folder = os.path.dirname(outpath)
pkl_files = glob.glob(os.path.join(folder, "*.pkl"))
model_files = glob.glob(os.path.join(folder, "*.pth"))

print("PKL files:", pkl_files)
print("Model files:", model_files)

# the load functionality automatically will build the pipeline object out of the three saved files
varix_loaded = acx.Maskix.load(outpath)
varix_loaded.predict(data=maskix_result.datasets)
varix_loaded.visualize()
varix_loaded.show_result()
# Out:
# Preprocessor saved successfully.
# saving memory efficient
# Pipeline object saved successfully.
# PKL files: ['tutorial_res/ontix.pkl', 'tutorial_res/ontix_reactome.pkl', 'tutorial_res/imagix.pkl', 'tutorial_res/ontix_preprocessor.pkl', 'tutorial_res/xmodalix.pkl', 'tutorial_res/ontix_reactome_preprocessor.pkl', 'tutorial_res/xmodalix_preprocessor.pkl', 'tutorial_res/imagix_preprocessor.pkl']
# Model files: ['tutorial_res/ontix_reactome_model.pth', 'tutorial_res/img.img_xmodalix_model.pth', 'tutorial_res/multi_bulk.rna_xmodalix_model.pth', 'tutorial_res/imagix_model.pth', 'tutorial_res/ontix_model.pth']
# Attempting to load a pipeline from tutorial_res/maskix...
# Pipeline object loaded successfully. Actual type: Maskix
# Preprocessor loaded successfully.
# /Users/maximilianjoas/development/autoencodix_package/src/autoencodix/losses/maskix_loss.py:38: UserWarning: You chose loss reduction: sum, this deviates from the implementation in the literature for this architecture, the authors used 'mean'
#   warnings.warn(
# /Users/maximilianjoas/development/autoencodix_package/src/autoencodix/visualize/_general_visualizer.py:51: UserWarning: We could not create visualizations for the loss plots.
# This usually happens if you try to visualize after saving and loading the pipeline object with `save_all=False`. This memory-efficient saving mode does not retain past training loss data.
#
# Original error message: Number of columns must be a positive integer, not 0
#   warnings.warn(
# /Users/maximilianjoas/development/autoencodix_package/src/autoencodix/base/_base_pipeline.py:1000: UserWarning: No loss data found in results. Skipping loss curve visualization.
#   warnings.warn(
# /Users/maximilianjoas/development/autoencodix_package/src/autoencodix/utils/_result.py:346: UserWarning: We could not create visualizations for the loss plots.
# This usually happens if you try to visualize after saving and loading the pipeline object with `save_all=False`. This memory-efficient saving mode does not retain past training loss data.
#
# Original error message: tuple index out of range
#   warnings.warn(
# /Users/maximilianjoas/development/autoencodix_package/src/autoencodix/utils/_result.py:346: UserWarning: We could not create visualizations for the loss plots.
# This usually happens if you try to visualize after saving and loading the pipeline object with `save_all=False`. This memory-efficient saving mode does not retain past training loss data.
#
# Original error message: tuple index out of range
#   warnings.warn(
# Creating plots ...
# /Users/maximilianjoas/development/autoencodix_package/src/autoencodix/utils/_result.py:346: UserWarning: We could not create visualizations for the loss plots.
# This usually happens if you try to visualize after saving and loading the pipeline object with `save_all=False`. This memory-efficient saving mode does not retain past training loss data.
#
# Original error message: tuple index out of range
#   warnings.warn(
# /Users/maximilianjoas/development/autoencodix_package/src/autoencodix/utils/_result.py:346: UserWarning: We could not create visualizations for the loss plots.
# This usually happens if you try to visualize after saving and loading the pipeline object with `save_all=False`. This memory-efficient saving mode does not retain past training loss data.
#
# Original error message: tuple index out of range
#   warnings.warn(
